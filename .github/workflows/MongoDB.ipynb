# %%
pip install pymongo[srv]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -tplotlib (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tplotlib (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tplotlib (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\young\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\young\anaconda3\lib\site-packages)
# ...

# %%
import pymongo
import cx_Oracle
import pandas as pd
import numpy as np
from tqdm import trange
import sqlalchemy
from sqlalchemy import create_engine
import csv

# %%
client = pymongo.MongoClient("mongodb+srv://youngcher:Chldudcjf12!@cluster0.j4ichm0.mongodb.net/?retryWrites=true&w=majority")

# %%
db = client.get_database('test1')

# %%
db = client['mac']

# %%
cl = db.get_collection('mac_sales')

# %%
file = pd.read_csv('C:/Users/young/OneDrive/바탕 화면/영철이팀/data_table/sales.csv', encoding="cp949")

# %%
file
# Out:
#         STDR_YY_CD  STDR_QU_CD TRDAR_SE_CD TRDAR_SE_CD_NM  TRDAR_CD  \
# 0             2017           1           A           골목상권   2110001
# 1             2017           1           A           골목상권   2110001
# 2             2017           1           A           골목상권   2110001
# 3             2017           1           A           골목상권   2110001
# 4             2017           1           A           골목상권   2110001
# ...            ...         ...         ...            ...       ...
# 791413        2021           4           U           관광특구   1001496
# 791414        2021           4           U           관광특구   1001496
# 791415        2021           4           U           관광특구   1001496
# 791416        2021           4           U           관광특구   1001496
# 791417        2021           4           U           관광특구   1001496
#
#         TRDAR_CD_NM SVC_INDUTY_CD SVC_INDUTY_CD_NM  THSMON_SELNG_AMT  \
# 0            이북5도청사      CS100001            한식음식점      8.168902e+08
# ...

# %%
file2 = file.head()
file2
# Out:
#    STDR_YY_CD  STDR_QU_CD TRDAR_SE_CD TRDAR_SE_CD_NM  TRDAR_CD TRDAR_CD_NM  \
# 0        2017           1           A           골목상권   2110001      이북5도청사
# 1        2017           1           A           골목상권   2110001      이북5도청사
# 2        2017           1           A           골목상권   2110001      이북5도청사
# 3        2017           1           A           골목상권   2110001      이북5도청사
# 4        2017           1           A           골목상권   2110001      이북5도청사
#
#   SVC_INDUTY_CD SVC_INDUTY_CD_NM  THSMON_SELNG_AMT  THSMON_SELNG_CO  ...  \
# 0      CS100001            한식음식점       816890247.0            28082  ...
# 1      CS100007            치킨전문점        19223252.0              517  ...
# 2      CS100008            분식전문점        75483418.0             5755  ...
# 3      CS100009          호프-간이주점        46115226.0             1306  ...
# 4      CS100010            커피-음료        22041409.0             1607  ...
#
#    TMZON_21_24_SELNG_CO  ML_SELNG_CO  FML_SELNG_CO  AGRDE_10_SELNG_CO  \
# ...

# %%
cl.insert_many(file.to_dict('records'))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1064/18788478.py in <module>
# ----> 1 cl.insert_many(file.to_dict('records'))
#
# ~\Anaconda3\lib\site-packages\pymongo\_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     705         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     706         blk.ops = [doc for doc in gen()]
# --> 707         blk.execute(write_concern, session=session)
# ...

# %%
print(cl.estimated_document_count())
# Out:
# 380278
